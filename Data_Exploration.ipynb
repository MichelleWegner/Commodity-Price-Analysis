# %%
conda install -c conda-forge prophet
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
#  - anaconda
# Platform: osx-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/anaconda3
#
#   added / updated specs:
#     - prophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.7.4   |       h8857fd0_0         151 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     clang-14.0.6               |       h694c41f_0         127 KB  conda-forge
#     clang-14-14.0.6            |default_h55ffa42_0         973 KB  conda-forge
#     clang_osx-64-14.0.6        |       h3113cd8_6          20 KB  conda-forge
#     clangxx-14.0.6             |default_h55ffa42_0         127 KB  conda-forge
#     clangxx_osx-64-14.0.6      |       h6f97653_6          19 KB  conda-forge
# ...

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
